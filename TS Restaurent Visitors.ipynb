# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# model in restaurant visitors

# %%
#hodliday is x factor

# %%
# last few entries are blank we have to forecast for that days

# %%
rv = pd.read_csv(r"C:\Users\maner\OneDrive\Desktop\New folder\Pandas dataset\RestaurantVisitors.csv", index_col= 'date', parse_dates= True)

# %%
rv
# Out:
#               weekday  holiday    holiday_name  rest1  rest2  rest3  rest4  \
# date
# 2016-01-01     Friday        1  New Year's Day   65.0   25.0   67.0  139.0
# 2016-01-02   Saturday        0              na   24.0   39.0   43.0   85.0
# 2016-01-03     Sunday        0              na   24.0   31.0   66.0   81.0
# 2016-01-04     Monday        0              na   23.0   18.0   32.0   32.0
# 2016-01-05    Tuesday        0              na    2.0   15.0   38.0   43.0
# ...               ...      ...             ...    ...    ...    ...    ...
# 2017-05-27   Saturday        0              na    NaN    NaN    NaN    NaN
# 2017-05-28     Sunday        0              na    NaN    NaN    NaN    NaN
# 2017-05-29     Monday        1    Memorial Day    NaN    NaN    NaN    NaN
# 2017-05-30    Tuesday        0              na    NaN    NaN    NaN    NaN
# 2017-05-31  Wednesday        0              na    NaN    NaN    NaN    NaN
#
#             total
# date
# 2016-01-01  296.0
# ...

# %%
rv[rv.total.isnull()]
# Out:
#               weekday  holiday   holiday_name  rest1  rest2  rest3  rest4  \
# date
# 2017-04-23     Sunday        0             na    NaN    NaN    NaN    NaN
# 2017-04-24     Monday        0             na    NaN    NaN    NaN    NaN
# 2017-04-25    Tuesday        0             na    NaN    NaN    NaN    NaN
# 2017-04-26  Wednesday        0             na    NaN    NaN    NaN    NaN
# 2017-04-27   Thursday        0             na    NaN    NaN    NaN    NaN
# 2017-04-28     Friday        0             na    NaN    NaN    NaN    NaN
# 2017-04-29   Saturday        0             na    NaN    NaN    NaN    NaN
# 2017-04-30     Sunday        0             na    NaN    NaN    NaN    NaN
# 2017-05-01     Monday        0             na    NaN    NaN    NaN    NaN
# 2017-05-02    Tuesday        0             na    NaN    NaN    NaN    NaN
# 2017-05-03  Wednesday        0             na    NaN    NaN    NaN    NaN
# 2017-05-04   Thursday        0             na    NaN    NaN    NaN    NaN
# ...

# %%
rv1 =rv.loc[:,['holiday','total']]
rv1 = rv1.dropna()

# %%
rv1.head()
# Out:
#             holiday  total
# date
# 2016-01-01        1  296.0
# 2016-01-02        0  191.0
# 2016-01-03        0  202.0
# 2016-01-04        0  105.0
# 2016-01-05        0   98.0

# %%
# we can observe that values are increasing from fri to sun and decreasing on monday
# data is seasonal with time period of 7

# %%
plt.figure(figsize=(10,6))
plt.plot(rv.total)
# Data is stationary

# %%
# sequential sampling
rv1_train = rv1.iloc[0:450]
rv1_test = rv1.iloc[450::]

# %%
# lets build a SARIMAx models
from pmdarima import auto_arima

# %%
auto_arima(rv1.total, seasonal=True, m=7, exogenous = rv1[['holiday']])
# taking holiday column as exogenous factor
# Out:
# ARIMA(order=(0, 0, 0), scoring_args={}, seasonal_order=(1, 0, 1, 7),
#       suppress_warnings=True)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model_sarimax_rv = SARIMAX(rv1_train.total, order = (1,0,0), seasonal_order = (1,0,1,7), exog = rv1_train[['holiday']])
# note in auto arima we are using exogenous =  and in sarima we are using exog
# Out:
# C:\Users\maner\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
result_sarimax = model_sarimax_rv.fit()

# %%
pred_sarimax = result_sarimax.predict(start = 450, end = 477, exog = rv1_test[['holiday']])

# %%
err_sarimax = rv1_test.total - pred_sarimax

# %%
mse_sarimax = np.mean(np.square(err_sarimax))
mse_sarimax
# Out:
# 359.2011908339215

# %%
mape_sarimax = np.mean(np.abs(err_sarimax*100/rv1_test.total))
mape_sarimax
# Out:
# 12.22587265200193

# %%
plt.figure(figsize = (10,2))
plt.plot(rv1.total)
plt.plot(pred_sarimax)

# %%
100-12.22
# Out:
# 87.78
